# %%
import os
import json

# %%
# Directory containing JSON files
json_dir = "Raw_data"  # Change this to your actual directory

# List to store all merged data
merged_data = []

# Iterate over all JSON files in the directory
for filename in os.listdir(json_dir):
    if filename.endswith(".json"):  # Ensure it's a JSON file
        file_path = os.path.join(json_dir, filename)

        # Load JSON file
        with open(file_path, "r", encoding="utf-8") as file:
            json_data = json.load(file)

            # Append each file's data into merged_data
            merged_data.extend(json_data)

# Save the merged data to a single JSON file
with open("merged_questionnaires.json", "w", encoding="utf-8") as output_file:
    json.dump(merged_data, output_file, indent=4)

print("Merged JSON data with all information saved successfully!")
# Out:
# Merged JSON data with all information saved successfully!

# %%
import pandas as pd

# %%
with open("merged_questionnaires.json", "r", encoding="utf-8") as file:
    json_data = json.load(file)

# Extract relevant fields
data = []
for entry in json_data:
    question_type = entry["type"]
    question = entry["question"]
    for option in entry["options"]:
        data.append([question_type, question, option["option"]])

# Create DataFrame
df_questionnaires = pd.DataFrame(data, columns=["Type", "Question", "Label"])
print(df_questionnaires)
# Out:
#               Type                  Question              Label
# 0    SINGLE_SELECT             Customer type       New customer
# 1    SINGLE_SELECT             Customer type  Existing customer
# 2    SINGLE_SELECT             Customer type            Partner
# 3    SINGLE_SELECT             Customer type          Applicant
# 4    SINGLE_SELECT     Customer satisfaction     Very satisfied
# ..             ...                       ...                ...
# 111   MULTI_SELECT  Who to copy in follow up      Sandro Kalter
# 112   MULTI_SELECT  Who to copy in follow up     Jens Roschmann
# 113   MULTI_SELECT  Who to copy in follow up       Domiki Stein
# 114   MULTI_SELECT  Who to copy in follow up        Sean Kennin
# 115   MULTI_SELECT  Who to copy in follow up        Tim Persson
#
# [116 rows x 3 columns]

# %%
df_single_select_questions = df_questionnaires[df_questionnaires["Type"] == "SINGLE_SELECT"]
df_single_select_questions
# Out:
#              Type                                           Question  \
# 0   SINGLE_SELECT                                      Customer type
# 1   SINGLE_SELECT                                      Customer type
# 2   SINGLE_SELECT                                      Customer type
# 3   SINGLE_SELECT                                      Customer type
# 4   SINGLE_SELECT                              Customer satisfaction
# 5   SINGLE_SELECT                              Customer satisfaction
# 6   SINGLE_SELECT                              Customer satisfaction
# 7   SINGLE_SELECT                              Customer satisfaction
# 8   SINGLE_SELECT           Size of the trade fair team (on average)
# 9   SINGLE_SELECT           Size of the trade fair team (on average)
# 10  SINGLE_SELECT           Size of the trade fair team (on average)
# 11  SINGLE_SELECT           Size of the trade fair team (on average)
# 12  SINGLE_SELECT           Size of the trade fair team (on average)
# 13  SINGLE_SELECT           Size of the trade fair team (on average)
# 14  SINGLE_SELECT           Size of the trade fair team (on average)
# 15  SINGLE_SELECT                                         CRM-System
# 16  SINGLE_SELECT                                         CRM-System
# 17  SINGLE_SELECT                                         CRM-System
# 18  SINGLE_SELECT                                         CRM-System
# 19  SINGLE_SELECT                                         CRM-System
# 20  SINGLE_SELECT                                         CRM-System
# 21  SINGLE_SELECT                                         CRM-System
# 22  SINGLE_SELECT                                         CRM-System
# 33  SINGLE_SELECT                                         Next steps
# 34  SINGLE_SELECT                                         Next steps
# 35  SINGLE_SELECT                                         Next steps
# 36  SINGLE_SELECT       Which language is wanted for communication?
# 37  SINGLE_SELECT       Which language is wanted for communication?
# 38  SINGLE_SELECT       Which language is wanted for communication?
# 39  SINGLE_SELECT       Which language is wanted for communication?
# 40  SINGLE_SELECT       Which language is wanted for communication?
# 56  SINGLE_SELECT                        What type of company is it?
# 57  SINGLE_SELECT                        What type of company is it?
# 58  SINGLE_SELECT                        What type of company is it?
# 59  SINGLE_SELECT                        What type of company is it?
# 60  SINGLE_SELECT                        What type of company is it?
# 61  SINGLE_SELECT                        What type of company is it?
# 62  SINGLE_SELECT                  What is the size of your company?
# 63  SINGLE_SELECT                  What is the size of your company?
# 64  SINGLE_SELECT                  What is the size of your company?
# 65  SINGLE_SELECT                  What is the size of your company?
# 66  SINGLE_SELECT                  What is the size of your company?
# 69  SINGLE_SELECT  Would you like to receive marketing informatio...
# 70  SINGLE_SELECT  Would you like to receive marketing informatio...
# 71  SINGLE_SELECT                What industry are you operating in?
# 72  SINGLE_SELECT                What industry are you operating in?
# 73  SINGLE_SELECT                What industry are you operating in?
# 74  SINGLE_SELECT                What industry are you operating in?
# 75  SINGLE_SELECT                What industry are you operating in?
# 76  SINGLE_SELECT                What industry are you operating in?
# 77  SINGLE_SELECT                What industry are you operating in?
# 78  SINGLE_SELECT                What industry are you operating in?
# 79  SINGLE_SELECT                What industry are you operating in?
# 80  SINGLE_SELECT                What industry are you operating in?
# 87  SINGLE_SELECT                            Data processing consent
# 88  SINGLE_SELECT                            Data processing consent
# 89  SINGLE_SELECT                                     Customer group
# 90  SINGLE_SELECT                                     Customer group
# 91  SINGLE_SELECT                                     Customer group
# 92  SINGLE_SELECT                                     Customer group
#
#                                  Label
# 0                         New customer
# 1                    Existing customer
# 2                              Partner
# 3                            Applicant
# 4                       Very satisfied
# 5                            Satisfied
# 6                          Unsatisfied
# 7                     Very unsatisfied
# 8                                  1-5
# 9                                 6-10
# 10                               11-15
# 11                               16-20
# 12                               21-30
# 13                               31-40
# 14                        more than 40
# 15                          Salesforce
# 16                           Pipedrive
# 17                            Close.io
# 18                  Microsoft Dynamics
# 19                             HubSpot
# 20                                 CAS
# 21                     SAP Sales Cloud
# 22                               Adito
# 33                               Offer
# 34                             Meeting
# 35                                Call
# 36                              German
# 37                             Italian
# 38                           Japanese
# 39                             English
# 40                             Spanish
# 56                Construction company
# 57                   Craft enterprises
# 58                 Scaffolding company
# 59                     Trading company
# 60                  Production company
# 61                    Education sector
# 62                                1-10
# 63                               11-50
# 64                              51-200
# 65                            201-2000
# 66                    larger than 2000
# 69                                 Yes
# 70                                  No
# 71                           Aerospace
# 72                Computers & Networks
# 73                          Government
# 74                             Medical
# 75                          Automotive
# 76                             Defense
# 77                          Industrial
# 78  Network Operators & Infrastructure
# 79     Public Safety / Law Enforcement
# 80                   Physical Security
# 87                                 Yes
# 88                                  No
# 89                            End User
# 90             Wholesaler, Distributor
# 91      Consultant, Planner, Architect
# 92                                 R&D

# %%
import google.generativeai as genai

# %%
genai.configure(api_key="")

# %%
def api_call_for_generating_question(question):
    try:
        model = genai.GenerativeModel("gemini-1.5-flash")
        #prompt = f"Generate diverse responses for the following question with the answer label '{label}': {question}"
        prompt = f"Generate a full understandable and short question based on the following: {question}. Direct the message to me. Print the question only!"

        response = model.generate_content(prompt)
        #print(response.text.strip())
        return response.text.strip()
    except Exception as e:
        print(f"Error with Gemini API: {e}")
        return prompt  # Fallback to original if API fails

# %%
import time

# %%
def generate_question(df):
    generated_questions = dict()

    for question in df["Question"]:

        if question not in generated_questions.keys():
            full_question = api_call_for_generating_question(question)
            generated_questions[question] = full_question
            print(f"{question}: {full_question}")
            time.sleep(3)
            
    df['Question'] = df['Question'].map(generated_questions)
    #print("Questions in dataframe with new Questions replaced.")

    return df

# %%
df_single_select_questions = generate_question(df_single_select_questions)
# Out:
# Customer type: What type of customer are you?
# Customer satisfaction: How satisfied are you with our service?
# Size of the trade fair team (on average): What's the average size of your trade fair team?
# CRM-System: What CRM system are you currently using?
# Next steps: What are the next steps?
# Which language is wanted for communication? : What language should we use to communicate?
# What type of company is it?: What kind of company is this?
# What is the size of your company?: How many people work at your company?
# Would you like to receive marketing information from via e-mail?: Want email marketing updates?
# What industry are you operating in?: What industry are you in?
# Data processing consent: Do you consent to the processing of your data?
# Customer group: What is the specific customer group you're targeting?
# /tmp/ipykernel_46677/1967883999.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Question'] = df['Question'].map(generated_questions)

# %%
df_single_select_questions
# Out:
#              Type                                           Question  \
# 0   SINGLE_SELECT                     What type of customer are you?
# 1   SINGLE_SELECT                     What type of customer are you?
# 2   SINGLE_SELECT                     What type of customer are you?
# 3   SINGLE_SELECT                     What type of customer are you?
# 4   SINGLE_SELECT            How satisfied are you with our service?
# 5   SINGLE_SELECT            How satisfied are you with our service?
# 6   SINGLE_SELECT            How satisfied are you with our service?
# 7   SINGLE_SELECT            How satisfied are you with our service?
# 8   SINGLE_SELECT   What's the average size of your trade fair team?
# 9   SINGLE_SELECT   What's the average size of your trade fair team?
# 10  SINGLE_SELECT   What's the average size of your trade fair team?
# 11  SINGLE_SELECT   What's the average size of your trade fair team?
# 12  SINGLE_SELECT   What's the average size of your trade fair team?
# 13  SINGLE_SELECT   What's the average size of your trade fair team?
# 14  SINGLE_SELECT   What's the average size of your trade fair team?
# 15  SINGLE_SELECT           What CRM system are you currently using?
# 16  SINGLE_SELECT           What CRM system are you currently using?
# 17  SINGLE_SELECT           What CRM system are you currently using?
# 18  SINGLE_SELECT           What CRM system are you currently using?
# 19  SINGLE_SELECT           What CRM system are you currently using?
# 20  SINGLE_SELECT           What CRM system are you currently using?
# 21  SINGLE_SELECT           What CRM system are you currently using?
# 22  SINGLE_SELECT           What CRM system are you currently using?
# 33  SINGLE_SELECT                           What are the next steps?
# 34  SINGLE_SELECT                           What are the next steps?
# 35  SINGLE_SELECT                           What are the next steps?
# 36  SINGLE_SELECT        What language should we use to communicate?
# 37  SINGLE_SELECT        What language should we use to communicate?
# 38  SINGLE_SELECT        What language should we use to communicate?
# 39  SINGLE_SELECT        What language should we use to communicate?
# 40  SINGLE_SELECT        What language should we use to communicate?
# 56  SINGLE_SELECT                      What kind of company is this?
# 57  SINGLE_SELECT                      What kind of company is this?
# 58  SINGLE_SELECT                      What kind of company is this?
# 59  SINGLE_SELECT                      What kind of company is this?
# 60  SINGLE_SELECT                      What kind of company is this?
# 61  SINGLE_SELECT                      What kind of company is this?
# 62  SINGLE_SELECT              How many people work at your company?
# 63  SINGLE_SELECT              How many people work at your company?
# 64  SINGLE_SELECT              How many people work at your company?
# 65  SINGLE_SELECT              How many people work at your company?
# 66  SINGLE_SELECT              How many people work at your company?
# 69  SINGLE_SELECT                      Want email marketing updates?
# 70  SINGLE_SELECT                      Want email marketing updates?
# 71  SINGLE_SELECT                          What industry are you in?
# 72  SINGLE_SELECT                          What industry are you in?
# 73  SINGLE_SELECT                          What industry are you in?
# 74  SINGLE_SELECT                          What industry are you in?
# 75  SINGLE_SELECT                          What industry are you in?
# 76  SINGLE_SELECT                          What industry are you in?
# 77  SINGLE_SELECT                          What industry are you in?
# 78  SINGLE_SELECT                          What industry are you in?
# 79  SINGLE_SELECT                          What industry are you in?
# 80  SINGLE_SELECT                          What industry are you in?
# 87  SINGLE_SELECT     Do you consent to the processing of your data?
# 88  SINGLE_SELECT     Do you consent to the processing of your data?
# 89  SINGLE_SELECT  What is the specific customer group you're tar...
# 90  SINGLE_SELECT  What is the specific customer group you're tar...
# 91  SINGLE_SELECT  What is the specific customer group you're tar...
# 92  SINGLE_SELECT  What is the specific customer group you're tar...
#
#                                  Label
# 0                         New customer
# 1                    Existing customer
# 2                              Partner
# 3                            Applicant
# 4                       Very satisfied
# 5                            Satisfied
# 6                          Unsatisfied
# 7                     Very unsatisfied
# 8                                  1-5
# 9                                 6-10
# 10                               11-15
# 11                               16-20
# 12                               21-30
# 13                               31-40
# 14                        more than 40
# 15                          Salesforce
# 16                           Pipedrive
# 17                            Close.io
# 18                  Microsoft Dynamics
# 19                             HubSpot
# 20                                 CAS
# 21                     SAP Sales Cloud
# 22                               Adito
# 33                               Offer
# 34                             Meeting
# 35                                Call
# 36                              German
# 37                             Italian
# 38                           Japanese
# 39                             English
# 40                             Spanish
# 56                Construction company
# 57                   Craft enterprises
# 58                 Scaffolding company
# 59                     Trading company
# 60                  Production company
# 61                    Education sector
# 62                                1-10
# 63                               11-50
# 64                              51-200
# 65                            201-2000
# 66                    larger than 2000
# 69                                 Yes
# 70                                  No
# 71                           Aerospace
# 72                Computers & Networks
# 73                          Government
# 74                             Medical
# 75                          Automotive
# 76                             Defense
# 77                          Industrial
# 78  Network Operators & Infrastructure
# 79     Public Safety / Law Enforcement
# 80                   Physical Security
# 87                                 Yes
# 88                                  No
# 89                            End User
# 90             Wholesaler, Distributor
# 91      Consultant, Planner, Architect
# 92                                 R&D

# %%
def make_api_call_for_answers(question, label):
    try:
        model = genai.GenerativeModel("gemini-1.5-flash")
        #prompt = f"Generate diverse responses for the following question with the answer label '{label}': {question}"
        prompt = f"Generate 100 full diverse answers as one sentence split in rows for the following context '{question}' with the answer label : '{label}'. Print the answers ONLY. If the label is yes or no also include answers without the label."
        
        response = model.generate_content(prompt)
        print(f"Answers for Question \"{question}\" with label \"{label}\" generated.")
        return response.text.strip()
    except Exception as e:
        print(f"Error with Gemini API: {e}")
        return prompt  # Fallback to original if API fails

# %%
import datetime

# %%
def generate_diverse_answers(df):

    generated_answers = []

    for _, row in df.iterrows():
        type = row["Type"]
        question = row["Question"]
        label = row["Label"]

        answers = make_api_call_for_answers(question, label)

        each_response = answers.split("\n")

        for curr_response in each_response:
                generated_answers.append({
                    #'question_id': row['question_id'],
                    'question': question,
                    'type': type,
                    'answer_text': curr_response,
                    'answer_label': label,
                    'timestamp': datetime.datetime.now().strftime("%Y-%m-%dT%H:%M:%S.%f")  # Aktueller Timestamp
                })
        
        time.sleep(3)

    return generated_answers

# %%
df_single_select_with_new_q_and_a = generate_diverse_answers(df_single_select_questions)
# Out:
# Answers for Question "What type of customer are you?" with label "New customer" generated.
# Answers for Question "What type of customer are you?" with label "Existing customer" generated.
# Answers for Question "What type of customer are you?" with label "Partner" generated.
# Answers for Question "What type of customer are you?" with label "Applicant" generated.
# Answers for Question "How satisfied are you with our service?" with label "Very satisfied" generated.
# Answers for Question "How satisfied are you with our service?" with label "Satisfied" generated.
# Answers for Question "How satisfied are you with our service?" with label "Unsatisfied" generated.
# Answers for Question "How satisfied are you with our service?" with label "Very unsatisfied" generated.
# Answers for Question "What's the average size of your trade fair team?" with label "1-5" generated.
# Answers for Question "What's the average size of your trade fair team?" with label "6-10" generated.
# Answers for Question "What's the average size of your trade fair team?" with label "11-15" generated.
# Answers for Question "What's the average size of your trade fair team?" with label "16-20" generated.
# Answers for Question "What's the average size of your trade fair team?" with label "21-30" generated.
# Answers for Question "What's the average size of your trade fair team?" with label "31-40" generated.
# Answers for Question "What's the average size of your trade fair team?" with label "more than 40" generated.
# Answers for Question "What CRM system are you currently using?" with label "Salesforce" generated.
# Answers for Question "What CRM system are you currently using?" with label "Pipedrive" generated.
# Answers for Question "What CRM system are you currently using?" with label "Close.io" generated.
# Answers for Question "What CRM system are you currently using?" with label "Microsoft Dynamics" generated.
# Answers for Question "What CRM system are you currently using?" with label "HubSpot" generated.
# Answers for Question "What CRM system are you currently using?" with label "CAS" generated.
# Answers for Question "What CRM system are you currently using?" with label "SAP Sales Cloud" generated.
# Answers for Question "What CRM system are you currently using?" with label "Adito" generated.
# Answers for Question "What are the next steps?" with label "Offer" generated.
# Answers for Question "What are the next steps?" with label "Meeting" generated.
# Answers for Question "What are the next steps?" with label "Call" generated.
# Answers for Question "What language should we use to communicate?" with label "German" generated.
# Answers for Question "What language should we use to communicate?" with label "Italian" generated.
# Answers for Question "What language should we use to communicate?" with label "Japanese " generated.
# Answers for Question "What language should we use to communicate?" with label "English" generated.
# Answers for Question "What language should we use to communicate?" with label "Spanish" generated.
# Answers for Question "What kind of company is this?" with label "Construction company" generated.
# Answers for Question "What kind of company is this?" with label "Craft enterprises" generated.
# Answers for Question "What kind of company is this?" with label "Scaffolding company" generated.
# Answers for Question "What kind of company is this?" with label "Trading company" generated.
# Answers for Question "What kind of company is this?" with label "Production company" generated.
# Answers for Question "What kind of company is this?" with label "Education sector" generated.
# Answers for Question "How many people work at your company?" with label "1-10" generated.
# Answers for Question "How many people work at your company?" with label "11-50" generated.
# Answers for Question "How many people work at your company?" with label "51-200" generated.
# Answers for Question "How many people work at your company?" with label "201-2000" generated.
# Answers for Question "How many people work at your company?" with label "larger than 2000" generated.
# Answers for Question "Want email marketing updates?" with label "Yes" generated.
# Answers for Question "Want email marketing updates?" with label "No" generated.
# Answers for Question "What industry are you in?" with label "Aerospace" generated.
# Answers for Question "What industry are you in?" with label "Computers & Networks" generated.
# Answers for Question "What industry are you in?" with label "Government" generated.
# Answers for Question "What industry are you in?" with label "Medical" generated.
# Answers for Question "What industry are you in?" with label "Automotive" generated.
# Answers for Question "What industry are you in?" with label "Defense" generated.
# Answers for Question "What industry are you in?" with label "Industrial" generated.
# Answers for Question "What industry are you in?" with label "Network Operators & Infrastructure" generated.
# Answers for Question "What industry are you in?" with label "Public Safety / Law Enforcement" generated.
# Answers for Question "What industry are you in?" with label "Physical Security" generated.
# Answers for Question "Do you consent to the processing of your data?" with label "Yes" generated.
# Answers for Question "Do you consent to the processing of your data?" with label "No" generated.
# Answers for Question "What is the specific customer group you're targeting?" with label "End User" generated.
# Answers for Question "What is the specific customer group you're targeting?" with label "Wholesaler, Distributor" generated.
# Answers for Question "What is the specific customer group you're targeting?" with label "Consultant, Planner, Architect" generated.
# Answers for Question "What is the specific customer group you're targeting?" with label "R&D" generated.

# %%
df_single_select_with_new_q_and_a
# Out:
# [{'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a first-time buyer exploring your offerings.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492617'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'This is my initial purchase from your company.',
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492675'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a new customer looking for information.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492687'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I've never used your services before.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492696'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a brand-new customer, excited to try your product.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492704'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a fresh customer interested in your solutions.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492713'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a recent customer exploring my options.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492721'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a potential new customer researching your business.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492728'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm completely new to your brand.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492736'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm trying your product or service for the first time.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492743'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a first-time visitor to your website.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492750'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'This is my very first interaction with your company.',
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492758'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a prospective customer making my initial inquiry.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492766'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a new customer seeking assistance.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492774'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a novice user of your platform.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492781'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a new user looking for a quick start guide.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492788'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm making my first purchase with you today.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492795'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a fresh customer ready to make a transaction.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492804'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'I just discovered your business and am impressed.',
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492811'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'I am a new customer seeking to sign up for your service.',
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492819'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm completely new to your company and its products.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492827'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a new customer interested in learning more about you.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492836'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'I just found your business and want to become a customer.',
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492844'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm exploring your services as a potential new customer.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492851'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a new customer seeking to understand your pricing.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492859'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a potential client checking out your offerings.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492867'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a first time customer looking for a specific item.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492875'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a new customer with a question about your return policy.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492882'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a first-timer interested in your customer loyalty program.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492889'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a new customer checking out your warranty information.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492897'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a fresh face, ready to experience your products.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492905'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm starting my journey with your company.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492912'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a new customer eager to start a subscription.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492920'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm initiating my relationship with your brand.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492928'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a new customer seeking tailored recommendations.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492935'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a prospective customer assessing your value proposition.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492942'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a newcomer to your ecosystem.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.492950'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a first-time customer, seeking to learn more about your company's history.",
#   'answer_label': 'New customer',
#   'timestamp': '2025-01-24T00:52:21.
",
#   'answer_label': 'Existing customer',
#   'timestamp': '2025-01-24T00:52:36.331805'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'I’m a returning customer, always satisfied with your prompt service.',
#   'answer_label': 'Existing customer',
#   'timestamp': '2025-01-24T00:52:36.331812'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm an existing customer with a problem I need resolved quickly.",
#   'answer_label': 'Existing customer',
#   'timestamp': '2025-01-24T00:52:36.331820'},
#  {'question': 'What type of customer are you?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm a customer who has recommended your service to others.",
#   'answer_label': 'Existing customer',
#   'timestamp': '2025-01-24T00:52:36.331828'},
#  {'question': 'What type of customer are you?',
# ...
#   'answer_label': 'Very unsatisfied',
#   'timestamp': '2025-01-24T00:53:57.658572'},
#  {'question': 'How satisfied are you with our service?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "The service was appalling; I'm extremely disappointed and angry.",
#   'answer_label': 'Very unsatisfied',
#   'timestamp': '2025-01-24T00:53:57.658577'},
#  {'question': 'How satisfied are you with our service?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm extremely dissatisfied with the negative experience I encountered.",
#   'answer_label': 'Very unsatisfied',
#   'timestamp': '2025-01-24T00:53:57.658582'},
#  {'question': 'How satisfied are you with our service?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm very unsatisfied with the way my request was handled improperly.",
#   'answer_label': 'Very unsatisfied',
#   'timestamp': '2025-01-24T00:53:57.658587'},
#  {'question': 'How satisfied are you with our service?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'The service was inefficient and lacked attention to detail.',
#   'answer_label': 'Very unsatisfied',
#   'timestamp': '2025-01-24T00:53:57.658595'},
#  {'question': 'How satisfied are you with our service?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm extremely unhappy with the repeated failures and mistakes.",
#   'answer_label': 'Very unsatisfied',
#   'timestamp': '2025-01-24T00:53:57.658600'},
#  {'question': 'How satisfied are you with our service?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm very unsatisfied with the constant need for follow-up and chasing.",
#   'answer_label': 'Very unsatisfied',
#   'timestamp': '2025-01-24T00:53:57.658605'},
#  {'question': 'How satisfied are you with our service?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'The service was poorly managed and poorly executed.',
#   'answer_label': 'Very unsatisfied',
#   'timestamp': '2025-01-24T00:53:57.658610'},
#  {'question': 'How satisfied are you with our service?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm extremely disappointed; the service was not worth the cost.",
#   'answer_label': 'Very unsatisfied',
#   'timestamp': '2025-01-24T00:53:57.658615'},
#  {'question': 'How satisfied are you with our service?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm very unsatisfied with the lack of proper training for staff.",
#   'answer_label': 'Very unsatisfied',
#   'timestamp': '2025-01-24T00:53:57.658619'},
#  {'question': 'How satisfied are you with our service?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'The service was a total waste of time, effort, and money.',
#   'answer_label': 'Very unsatisfied',
#   'timestamp': '2025-01-24T00:53:57.658624'},
#  {'question': 'How satisfied are you with our service?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm extremely unhappy with the overall lack of quality.",
#   'answer_label': 'Very unsatisfied',
#   'timestamp': '2025-01-24T00:53:57.658629'},
#  {'question': 'How satisfied are you with our service?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': "I'm very unsatisfied with the inability to reach anyone helpful.",
#   'answer_label': 'Very unsatisfied',
#   'timestamp': '2025-01-24T00:53:57.658633'},
#  {'question': 'How satisfied are you with our service?',
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'The service was truly abysmal and unacceptable.',
#   'answer_label': 'Very unsatisfied',
#   'timestamp': '2025-01-24T00:53:57.658638'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'Our trade fair team typically consists of between one and five members.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.213708'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'We usually have a small team of one to five people at trade fairs.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.213849'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'Our presence at trade shows is usually managed by a team of 1-5 individuals.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.213864'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'A small contingent of 1-5 people represents us at most trade fairs.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.213873'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'The size of our trade fair team fluctuates, but usually stays within the 1-5 range.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.213880'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'Our trade show team generally numbers between one and five individuals.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.213981'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'We send a team of one to five representatives to trade shows.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.213996'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'On average, we have a team of 1 to 5 people at our trade fair booth.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214005'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'Our trade fair participation involves a team of between one and five members.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214014'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'A small, agile team of 1-5 handles our trade fair presence.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214021'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'The team representing us at trade shows typically comprises 1-5 members.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214029'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'Our trade fair staff generally ranges from one to five individuals.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214037'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'We usually deploy a team of 1-5 people to manage our trade fair presence.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214045'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'Our trade fair team generally consists of between one and five individuals.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214052'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'Our booth at trade shows is staffed by 1-5 members of our team.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214059'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'For trade shows, we usually send a team of one to five people.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214066'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'At trade fairs, we typically utilize a small team, usually numbering 1-5.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214074'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'We have a small and efficient team of 1-5 at each trade fair.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214081'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'The number of personnel at our trade fairs is typically 1 to 5.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214088'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'Our team size at trade fairs averages between 1 and 5 people.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214095'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'It varies but generally we have between one and five people at our trade fair.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214102'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'We typically send a group of 1-5 people to represent us at trade fairs.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214109'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'Depending on the show, we send 1 to 5 people to our trade fair booth.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214117'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'The average number of people on our trade fair team is between 1 and 5.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214127'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'A team of 1 to 5 staff members typically represent us at trade shows.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214136'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'Our trade show team is usually comprised of between one and five people.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214143'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'We often have a team of 1-5 members at any given trade fair.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214151'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'Our typical trade show team size is between one and five people.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214158'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'The personnel at our trade fair booth usually numbers between one and five.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214166'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'Our trade fair representation generally involves a team of 1-5 people.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214182'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'Our trade fair presence is managed by a small team of 1-5 individuals.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214190'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': "The size of our trade fair team varies, but it's usually between 1 and 5.",
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214198'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'We generally have a small team, 1-5 people, at trade fairs.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214205'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'Between one and five people typically represent us at trade fairs.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214212'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'Our trade fair booth is staffed by a team averaging 1 to 5 members.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214220'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'Our team at trade shows is usually comprised of one to five members.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214227'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'The size of our trade fair team is usually between one and five.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214235'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'We have anywhere from one to five people on our trade fair team.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214242'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'Typically, our trade fair team comprises one to five individuals.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214250'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'Our presence at a trade fair is usually handled by a team of 1-5.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214257'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'Our trade show team generally ranges from one to a maximum of five.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214265'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'Our trade fair team numbers between one and five, depending on the event.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214272'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'The team we send to trade fairs usually has between one and five people.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214279'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'We send a small team, usually 1-5 people, to each trade fair.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214287'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'The number of people on our trade fair team typically ranges from 1-5.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214298'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'We usually have a small team of 1-5 people representing us.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214306'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'Our trade fair team usually consists of 1-5 members, give or take.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214314'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'At any given trade fair, we have a team of approximately 1-5 people.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214321'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'The average staffing level for our trade fair booth is 1-5 people.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214329'},
#  {'question': "What's the average size of your trade fair team?",
#   'type': 'SINGLE_SELECT',
#   'answer_text': 'The team size for our trade fair appearances is generally 1-5.',
#   'answer_label': '1-5',
#   'timestamp': '2025-01-24T00:54:12.214336'},
#  ...]

# %%
for entry in data:
    question_id = entry["question_id"]
    question = entry["question"]
    question_type = entry["type"]
    for answer in entry["answers"]:
        rows.append({
            "question_id": question_id,
            "question": question,
            "type": question_type,
            "answer_text": answer["text"],
            "answer_label": answer["label"],
            "timestamp": answer["timestamp"]
        })
# Out:
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a first-time buyer exploring your offerings.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492617'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': 'This is my initial purchase from your company.', 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492675'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a new customer looking for information.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492687'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I've never used your services before.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492696'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a brand-new customer, excited to try your product.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492704'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a fresh customer interested in your solutions.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492713'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a recent customer exploring my options.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492721'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a potential new customer researching your business.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492728'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm completely new to your brand.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492736'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm trying your product or service for the first time.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492743'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a first-time visitor to your website.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492750'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': 'This is my very first interaction with your company.', 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492758'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a prospective customer making my initial inquiry.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492766'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a new customer seeking assistance.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492774'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a novice user of your platform.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492781'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a new user looking for a quick start guide.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492788'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm making my first purchase with you today.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492795'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a fresh customer ready to make a transaction.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492804'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': 'I just discovered your business and am impressed.', 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492811'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': 'I am a new customer seeking to sign up for your service.', 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492819'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm completely new to your company and its products.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492827'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a new customer interested in learning more about you.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492836'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': 'I just found your business and want to become a customer.', 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492844'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm exploring your services as a potential new customer.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492851'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a new customer seeking to understand your pricing.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492859'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a potential client checking out your offerings.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492867'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a first time customer looking for a specific item.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492875'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a new customer with a question about your return policy.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492882'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a first-timer interested in your customer loyalty program.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492889'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a new customer checking out your warranty information.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492897'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a fresh face, ready to experience your products.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492905'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm starting my journey with your company.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492912'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a new customer eager to start a subscription.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492920'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm initiating my relationship with your brand.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492928'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a new customer seeking tailored recommendations.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492935'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a prospective customer assessing your value proposition.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492942'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a newcomer to your ecosystem.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492950'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a first-time customer, seeking to learn more about your company's history.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492958'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a new customer and have a couple of questions before purchasing.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492965'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a new customer curious about your sustainability practices.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492972'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a potential customer impressed with your positive online reviews.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492979'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a recent customer, still getting accustomed to your interface.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492987'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a new customer interested in your corporate social responsibility initiatives.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.492994'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': 'I just signed up for your newsletter and am now considering a purchase.', 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.493001'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a new customer, intrigued by your innovative approach.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.493008'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a new customer looking for exceptional customer service.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.493015'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a recent customer and want to provide feedback.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.493022'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a completely new customer with high expectations.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.493028'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a new customer and I'm ready to purchase immediately.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.493036'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a new customer and would appreciate some product samples.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.493042'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a new customer who found your company through a referral.", 'answer_label': 'New customer', 'timestamp': '2025-01-24T00:52:21.493049'}
# {'question': 'What type of customer are you?', 'type': 'SINGLE_SELECT', 'answer_text': "I'm a new customer
}
# {'question': "What is the specific customer group you're targeting?", 'type': 'SINGLE_SELECT', 'answer_text': 'Our ideal customer is the R&D division of a large space agency.', 'answer_label': 'R&D', 'timestamp': '2025-01-24T01:06:02.563661'}
# {'question': "What is the specific customer group you're targeting?", 'type': 'SINGLE_SELECT', 'answer_text': "We're concentrating on R&D professionals working on robotics and automation.", 'answer_label': 'R&D', 'timestamp': '2025-01-24T01:06:02.563667'}
# {'question': "What is the specific customer group you're targeting?", 'type': 'SINGLE_SELECT', 'answer_text': 'Our target market includes R&D engineers involved in the development of drones.', 'answer_label': 'R&D', 'timestamp': '2025-01-24T01:06:02.563673'}
# {'question': "What is the specific customer group you're targeting?", 'type': 'SINGLE_SELECT', 'answer_text': 'Our specific customer base is R&D personnel in the defense industry.', 'answer_label': 'R&D', 'timestamp': '2025-01-24T01:06:02.563679'}
# {'question': "What is the specific customer group you're targeting?", 'type': 'SINGLE_SELECT', 'answer_text': "We're aiming to reach R&D professionals working in the field of cybersecurity.", 'answer_label': 'R&D', 'timestamp': '2025-01-24T01:06:02.563685'}
# {'question': "What is the specific customer group you're targeting?", 'type': 'SINGLE_SELECT', 'answer_text': 'The specific customer group is R&D scientists developing new defense technologies.', 'answer_label': 'R&D', 'timestamp': '2025-01-24T01:06:02.563691'}
# {'question': "What is the specific customer group you're targeting?", 'type': 'SINGLE_SELECT', 'answer_text': 'Our focus is on R&D teams working on national security.', 'answer_label': 'R&D', 'timestamp': '2025-01-24T01:06:02.563697'}
# {'question': "What is the specific customer group you're targeting?", 'type': 'SINGLE_SELECT', 'answer_text': "We're targeting R&D professionals working in the field of intelligence.", 'answer_label': 'R&D', 'timestamp': '2025-01-24T01:06:02.563704'}

# %%
from collections import defaultdict

# %%
# Grouping data

def save_in_json(data):
    grouped_data = defaultdict(lambda: {'type': None, 'answers': []})

    for entry in data:
        question = entry['question']
        if grouped_data[question]['type'] is None:
            grouped_data[question]['type'] = entry['type']
        grouped_data[question]['answers'].append({
            'answer_text': entry['answer_text'],
            'answer_label': entry['answer_label'],
            'timestamp': entry['timestamp']
        })

    # Convert to final JSON structure
    final_json = [
        {
            'question': question,
            'type': details['type'],
            'answers': details['answers']
        }
        for question, details in grouped_data.items()
    ]

    # Save to file
    with open('final_single_question_data.json', 'w') as f:
        json.dump(final_json, f, indent=4)

    # Print output
    print(json.dumps(final_json, indent=4))

# %%
save_in_json(df_single_select_with_new_q_and_a)
# Out:
# [
#     {
#         "question": "What type of customer are you?",
#         "type": "SINGLE_SELECT",
#         "answers": [
#             {
#                 "answer_text": "I'm a first-time buyer exploring your offerings.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492617"
#             },
#             {
#                 "answer_text": "This is my initial purchase from your company.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492675"
#             },
#             {
#                 "answer_text": "I'm a new customer looking for information.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492687"
#             },
#             {
#                 "answer_text": "I've never used your services before.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492696"
#             },
#             {
#                 "answer_text": "I'm a brand-new customer, excited to try your product.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492704"
#             },
#             {
#                 "answer_text": "I'm a fresh customer interested in your solutions.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492713"
#             },
#             {
#                 "answer_text": "I'm a recent customer exploring my options.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492721"
#             },
#             {
#                 "answer_text": "I'm a potential new customer researching your business.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492728"
#             },
#             {
#                 "answer_text": "I'm completely new to your brand.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492736"
#             },
#             {
#                 "answer_text": "I'm trying your product or service for the first time.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492743"
#             },
#             {
#                 "answer_text": "I'm a first-time visitor to your website.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492750"
#             },
#             {
#                 "answer_text": "This is my very first interaction with your company.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492758"
#             },
#             {
#                 "answer_text": "I'm a prospective customer making my initial inquiry.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492766"
#             },
#             {
#                 "answer_text": "I'm a new customer seeking assistance.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492774"
#             },
#             {
#                 "answer_text": "I'm a novice user of your platform.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492781"
#             },
#             {
#                 "answer_text": "I'm a new user looking for a quick start guide.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492788"
#             },
#             {
#                 "answer_text": "I'm making my first purchase with you today.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492795"
#             },
#             {
#                 "answer_text": "I'm a fresh customer ready to make a transaction.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492804"
#             },
#             {
#                 "answer_text": "I just discovered your business and am impressed.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492811"
#             },
#             {
#                 "answer_text": "I am a new customer seeking to sign up for your service.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492819"
#             },
#             {
#                 "answer_text": "I'm completely new to your company and its products.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492827"
#             },
#             {
#                 "answer_text": "I'm a new customer interested in learning more about you.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492836"
#             },
#             {
#                 "answer_text": "I just found your business and want to become a customer.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492844"
#             },
#             {
#                 "answer_text": "I'm exploring your services as a potential new customer.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492851"
#             },
#             {
#                 "answer_text": "I'm a new customer seeking to understand your pricing.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492859"
#             },
#             {
#                 "answer_text": "I'm a potential client checking out your offerings.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492867"
#             },
#             {
#                 "answer_text": "I'm a first time customer looking for a specific item.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492875"
#             },
#             {
#                 "answer_text": "I'm a new customer with a question about your return policy.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492882"
#             },
#             {
#                 "answer_text": "I'm a first-timer interested in your customer loyalty program.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492889"
#             },
#             {
#                 "answer_text": "I'm a new customer checking out your warranty information.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492897"
#             },
#             {
#                 "answer_text": "I'm a fresh face, ready to experience your products.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492905"
#             },
#             {
#                 "answer_text": "I'm starting my journey with your company.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492912"
#             },
#             {
#                 "answer_text": "I'm a new customer eager to start a subscription.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492920"
#             },
#             {
#                 "answer_text": "I'm initiating my relationship with your brand.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492928"
#             },
#             {
#                 "answer_text": "I'm a new customer seeking tailored recommendations.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492935"
#             },
#             {
#                 "answer_text": "I'm a prospective customer assessing your value proposition.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492942"
#             },
#             {
#                 "answer_text": "I'm a newcomer to your ecosystem.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492950"
#             },
#             {
#                 "answer_text": "I'm a first-time customer, seeking to learn more about your company's history.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492958"
#             },
#             {
#                 "answer_text": "I'm a new customer and have a couple of questions before purchasing.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492965"
#             },
#             {
#                 "answer_text": "I'm a new customer curious about your sustainability practices.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492972"
#             },
#             {
#                 "answer_text": "I'm a potential customer impressed with your positive online reviews.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492979"
#             },
#             {
#                 "answer_text": "I'm a recent customer, still getting accustomed to your interface.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492987"
#             },
#             {
#                 "answer_text": "I'm a new customer interested in your corporate social responsibility initiatives.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.492994"
#             },
#             {
#                 "answer_text": "I just signed up for your newsletter and am now considering a purchase.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493001"
#             },
#             {
#                 "answer_text": "I'm a new customer, intrigued by your innovative approach.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493008"
#             },
#             {
#                 "answer_text": "I'm a new customer looking for exceptional customer service.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493015"
#             },
#             {
#                 "answer_text": "I'm a recent customer and want to provide feedback.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493022"
#             },
#             {
#                 "answer_text": "I'm a completely new customer with high expectations.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493028"
#             },
#             {
#                 "answer_text": "I'm a new customer and I'm ready to purchase immediately.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493036"
#             },
#             {
#                 "answer_text": "I'm a new customer and would appreciate some product samples.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493042"
#             },
#             {
#                 "answer_text": "I'm a new customer who found your company through a referral.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493049"
#             },
#             {
#                 "answer_text": "I'm a new customer who is impressed with the quality of your products.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493056"
#             },
#             {
#                 "answer_text": "I'm a new customer looking for affordable and reliable services.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493063"
#             },
#             {
#                 "answer_text": "I'm a first-time customer who has been recommended by a friend.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493070"
#             },
#             {
#                 "answer_text": "I'm a new customer interested in personalized offers and deals.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493077"
#             },
#             {
#                 "answer_text": "I'm a new customer looking for long-term partnerships.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493084"
#             },
#             {
#                 "answer_text": "I'm a new customer excited about the future of your company.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493091"
#             },
#             {
#                 "answer_text": "I'm a new customer seeking transparency and honesty.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493099"
#             },
#             {
#                 "answer_text": "I'm a new customer committed to environmental sustainability.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493106"
#             },
#             {
#                 "answer_text": "I'm a new customer searching for ethically sourced products.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493113"
#             },
#             {
#                 "answer_text": "I'm a new customer and want to support a local business.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493120"
#             },
#             {
#                 "answer_text": "I'm a new customer prioritizing high-quality customer support.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493127"
#             },
#             {
#                 "answer_text": "I'm a new customer who values efficiency and speed.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493134"
#             },
#             {
#                 "answer_text": "I'm a first-time customer who wants to understand your payment options.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493141"
#             },
#             {
#                 "answer_text": "I'm a new customer seeking flexibility and customization options.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493148"
#             },
#             {
#                 "answer_text": "I'm a new customer drawn to your unique brand identity.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493155"
#             },
#             {
#                 "answer_text": "I'm a new customer looking forward to a positive experience.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493163"
#             },
#             {
#                 "answer_text": "I'm a new customer ready to explore all your product offerings.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493171"
#             },
#             {
#                 "answer_text": "I'm a new customer intrigued by your innovative technology.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493179"
#             },
#             {
#                 "answer_text": "I'm a new customer impressed with the design of your website.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493188"
#             },
#             {
#                 "answer_text": "I'm a new customer and am highly satisfied so far.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493196"
#             },
#             {
#                 "answer_text": "I'm a new customer that needs assistance with my account setup.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493203"
#             },
#             {
#                 "answer_text": "I'm a new customer and am looking forward to future interactions.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493210"
#             },
#             {
#                 "answer_text": "I'm a new customer and appreciate the clear and concise communication.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493218"
#             },
#             {
#                 "answer_text": "I'm a new customer and am grateful for the helpful information.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493226"
#             },
#             {
#                 "answer_text": "I'm a new customer and am already planning my next purchase.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493233"
#             },
#             {
#                 "answer_text": "I'm a new customer who values honesty and integrity.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493240"
#             },
#             {
#                 "answer_text": "I'm a new customer seeking innovative and cutting-edge solutions.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493307"
#             },
#             {
#                 "answer_text": "I'm a new customer who appreciates a personalized approach.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493326"
#             },
#             {
#                 "answer_text": "I'm a new customer looking for durable and long-lasting products.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493335"
#             },
#             {
#                 "answer_text": "I'm a new customer who values exceptional customer service and support.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493345"
#             },
#             {
#                 "answer_text": "I'm a new customer impressed by the positive testimonials.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493353"
#             },
#             {
#                 "answer_text": "I'm a new customer interested in learning about your company culture.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493361"
#             },
#             {
#                 "answer_text": "I'm a new customer and have been impressed with your social media presence.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493370"
#             },
#             {
#                 "answer_text": "I'm a new customer who is eager to share my experience with others.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493380"
#             },
#             {
#                 "answer_text": "I'm a new customer who is seeking a trustworthy and reliable service.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493388"
#             },
#             {
#                 "answer_text": "I'm a new customer looking for a stress-free and easy shopping experience.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493397"
#             },
#             {
#                 "answer_text": "I'm a new customer that appreciates transparency and accountability.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493404"
#             },
#             {
#                 "answer_text": "I'm a new customer who values environmentally friendly practices.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493492"
#             },
#             {
#                 "answer_text": "I'm a new customer who is committed to sustainable and ethical consumption.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493514"
#             },
#             {
#                 "answer_text": "I'm a new customer who believes in supporting small businesses and entrepreneurs.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493525"
#             },
#             {
#                 "answer_text": "I'm a new customer looking for products that align with my values.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493533"
#             },
#             {
#                 "answer_text": "I'm a new customer impressed by the company\u2019s commitment to innovation.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493542"
#             },
#             {
#                 "answer_text": "I'm a new customer who appreciates the attention to detail in your products.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493551"
#             },
#             {
#                 "answer_text": "I'm a new customer looking for high-quality products at competitive prices.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493559"
#             },
#             {
#                 "answer_text": "I'm a new customer that is looking forward to a rewarding experience.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493566"
#             },
#             {
#                 "answer_text": "I'm a new customer and I'm very excited to be a part of your community.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493574"
#             },
#             {
#                 "answer_text": "I'm a new customer with a strong interest in your industry.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493581"
#             },
#             {
#                 "answer_text": "I'm a new customer eager to explore the various features and benefits.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493589"
#             },
#             {
#                 "answer_text": "I'm a new customer looking for outstanding value for money.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493597"
#             },
#             {
#                 "answer_text": "I'm a new customer who is passionate about the work your company does.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493605"
#             },
#             {
#                 "answer_text": "I'm a new customer who values your commitment to quality assurance.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493612"
#             },
#             {
#                 "answer_text": "I'm a new customer seeking professional and helpful guidance.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493620"
#             },
#             {
#                 "answer_text": "I'm a new customer impressed by your extensive product line.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493627"
#             },
#             {
#                 "answer_text": "I'm a new customer who appreciates your dedication to customer satisfaction.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493635"
#             },
#             {
#                 "answer_text": "I'm a new customer searching for a solution to a specific problem.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493643"
#             },
#             {
#                 "answer_text": "I'm a new customer interested in learning more about your future plans.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493650"
#             },
#             {
#                 "answer_text": "I'm a new customer excited about the potential for future collaboration.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493658"
#             },
#             {
#                 "answer_text": "I'm a new customer ready to provide constructive feedback and suggestions.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493666"
#             },
#             {
#                 "answer_text": "I'm a new customer seeking a reliable and dependable service provider.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493674"
#             },
#             {
#                 "answer_text": "I'm a new customer expecting excellent communication and responsiveness.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493682"
#             },
#             {
#                 "answer_text": "I'm a new customer who is delighted with the overall experience.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493690"
#             },
#             {
#                 "answer_text": "I'm a new customer with high hopes for a long-lasting relationship.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493698"
#             },
#             {
#                 "answer_text": "I'm a new customer seeking a seamless and effortless purchasing journey.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493705"
#             },
#             {
#                 "answer_text": "I'm a new customer seeking personalized recommendations to meet my needs.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493713"
#             },
#             {
#                 "answer_text": "I'm a new customer and am highly impressed with your responsiveness.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493720"
#             },
#             {
#                 "answer_text": "I'm a new customer and am very pleased with the entire purchase process.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493729"
#             },
#             {
#                 "answer_text": "I'm a new customer anticipating a long and fruitful relationship with your company.",
#                 "answer_label": "New customer",
#                 "timestamp": "2025-01-24T00:52:21.493736"
#             },
#             {
#                 "answer_text": "I've been a loyal customer for over five years.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331010"
#             },
#             {
#                 "answer_text": "I've purchased your products repeatedly in the past.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331065"
#             },
#             {
#                 "answer_text": "I'm a returning customer looking for more of the same.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331077"
#             },
#             {
#                 "answer_text": "I'm a repeat buyer, completely satisfied with your service.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331086"
#             },
#             {
#                 "answer_text": "As a long-term customer, I value your company's reliability.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331095"
#             },
#             {
#                 "answer_text": "I'm an existing customer seeking assistance with a previous order.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331103"
#             },
#             {
#                 "answer_text": "I've been a satisfied customer since [Year].",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331111"
#             },
#             {
#                 "answer_text": "I'm a repeat customer with a positive experience.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331119"
#             },
#             {
#                 "answer_text": "I'm an existing customer and a strong advocate for your brand.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331127"
#             },
#             {
#                 "answer_text": "I'm a current customer seeking information about a new product.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331135"
#             },
#             {
#                 "answer_text": "I'm a past customer returning for more of your quality items.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331143"
#             },
#             {
#                 "answer_text": "I've used your services many times and am very happy.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331152"
#             },
#             {
#                 "answer_text": "I am a regular customer, consistently purchasing your products.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331160"
#             },
#             {
#                 "answer_text": "I'm an existing customer needing technical support.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331168"
#             },
#             {
#                 "answer_text": "I'm a long-standing customer with a history of positive interactions.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331175"
#             },
#             {
#                 "answer_text": "I've been a customer since the company's inception.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331182"
#             },
#             {
#                 "answer_text": "I'm a repeat customer seeking to upgrade my current plan.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331189"
#             },
#             {
#                 "answer_text": "I'm an existing customer with questions about billing.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331196"
#             },
#             {
#                 "answer_text": "I am a valuable existing customer who deserves premium service.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331204"
#             },
#             {
#                 "answer_text": "I'm a returning customer with a specific request.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331211"
#             },
#             {
#                 "answer_text": "I have a history of purchasing from your business.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331218"
#             },
#             {
#                 "answer_text": "I'm a current customer looking to expand my services.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331226"
#             },
#             {
#                 "answer_text": "I've been a loyal customer for many years.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331234"
#             },
#             {
#                 "answer_text": "I'm a satisfied customer looking for similar products.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331242"
#             },
#             {
#                 "answer_text": "I'm an existing customer needing replacement parts.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331250"
#             },
#             {
#                 "answer_text": "My account history shows I'm a regular customer.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331258"
#             },
#             {
#                 "answer_text": "I am a returning customer seeking warranty support.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331268"
#             },
#             {
#                 "answer_text": "I am a long-term customer with a positive experience to share.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331276"
#             },
#             {
#                 "answer_text": "I\u2019m a faithful customer who appreciates your offerings.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331284"
#             },
#             {
#                 "answer_text": "I'm an existing customer with a great history of purchases.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331293"
#             },
#             {
#                 "answer_text": "I'm a returning customer seeking to resolve a minor issue.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331301"
#             },
#             {
#                 "answer_text": "I'm a past customer making another purchase.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331309"
#             },
#             {
#                 "answer_text": "I'm a highly satisfied returning customer.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331317"
#             },
#             {
#                 "answer_text": "I'm an existing customer seeking to cancel a service.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331324"
#             },
#             {
#                 "answer_text": "I have been consistently using your service for years.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331333"
#             },
#             {
#                 "answer_text": "I'm a current customer needing help with a technical problem.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331341"
#             },
#             {
#                 "answer_text": "I am a valuable and loyal existing customer.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331348"
#             },
#             {
#                 "answer_text": "I'm a returning customer seeking information about a renewal.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331355"
#             },
#             {
#                 "answer_text": "I'm an existing customer ready to upgrade my account.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331363"
#             },
#             {
#                 "answer_text": "I'm a customer who's purchased from you multiple times.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331371"
#             },
#             {
#                 "answer_text": "I'm an existing customer requesting a refund.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331378"
#             },
#             {
#                 "answer_text": "I am a customer with multiple accounts with your company.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331387"
#             },
#             {
#                 "answer_text": "I've been a customer for several years, always happy.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331394"
#             },
#             {
#                 "answer_text": "I'm an existing customer exploring new possibilities.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331401"
#             },
#             {
#                 "answer_text": "I'm a customer with a past purchase I'd like to discuss.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331409"
#             },
#             {
#                 "answer_text": "I'm a long-term customer seeking a discount.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331416"
#             },
#             {
#                 "answer_text": "I'm a regular customer, and I'm very happy.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331424"
#             },
#             {
#                 "answer_text": "I'm an existing customer needing assistance with my account.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331431"
#             },
#             {
#                 "answer_text": "I'm a loyal customer ready to make another purchase.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331438"
#             },
#             {
#                 "answer_text": "I've used your product(s)/service(s) before and am happy.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331532"
#             },
#             {
#                 "answer_text": "I'm a returning customer impressed with your quality.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331555"
#             },
#             {
#                 "answer_text": "I'm a customer with ongoing needs and purchases.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331565"
#             },
#             {
#                 "answer_text": "I'm an existing customer looking for additional support.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331574"
#             },
#             {
#                 "answer_text": "I have a strong track record as a loyal customer.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331583"
#             },
#             {
#                 "answer_text": "I'm a current customer and want to give feedback.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331591"
#             },
#             {
#                 "answer_text": "I\u2019m a returning customer, and I love your products!",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331599"
#             },
#             {
#                 "answer_text": "I'm an existing customer happy to recommend your brand.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331607"
#             },
#             {
#                 "answer_text": "I'm a satisfied customer with a successful past experience.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331615"
#             },
#             {
#                 "answer_text": "I'm an existing customer seeking clarification on pricing.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331622"
#             },
#             {
#                 "answer_text": "I'm a regular customer, pleased with your services.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331630"
#             },
#             {
#                 "answer_text": "I'm an existing customer requesting account modifications.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331637"
#             },
#             {
#                 "answer_text": "I am a previous customer returning for more service.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331645"
#             },
#             {
#                 "answer_text": "I am a valued existing customer with a proven track record.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331652"
#             },
#             {
#                 "answer_text": "I am an existing customer seeking to change my contact info.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331660"
#             },
#             {
#                 "answer_text": "I'm a customer who appreciates your dedicated support team.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331668"
#             },
#             {
#                 "answer_text": "I'm a returning customer wanting to expand my usage.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331675"
#             },
#             {
#                 "answer_text": "I\u2019m a returning customer with a question about a previous order.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331683"
#             },
#             {
#                 "answer_text": "I am an existing customer looking for special offers.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331691"
#             },
#             {
#                 "answer_text": "I'm a loyal customer ready to make a large purchase.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331699"
#             },
#             {
#                 "answer_text": "I've been a regular customer for years, and highly satisfied.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331707"
#             },
#             {
#                 "answer_text": "I'm a repeat customer providing feedback on my experience.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331714"
#             },
#             {
#                 "answer_text": "I'm an existing customer planning to upgrade soon.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331722"
#             },
#             {
#                 "answer_text": "I'm a current customer looking to renew my subscription.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331730"
#             },
#             {
#                 "answer_text": "I'm an existing customer satisfied with customer service.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331738"
#             },
#             {
#                 "answer_text": "I'm a returning customer seeking a specific product version.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331748"
#             },
#             {
#                 "answer_text": "I'm an existing customer and a potential referral source.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331756"
#             },
#             {
#                 "answer_text": "I'm a customer with several outstanding transactions.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331763"
#             },
#             {
#                 "answer_text": "I'm an existing customer seeking to add a user to my account.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331772"
#             },
#             {
#                 "answer_text": "I'm a past customer returning with a new need.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331780"
#             },
#             {
#                 "answer_text": "I'm a loyal customer, always impressed by your product quality.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331788"
#             },
#             {
#                 "answer_text": "I'm an existing customer seeking technical assistance.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331797"
#             },
#             {
#                 "answer_text": "I'm a repeat customer who\u2019s always found your services reliable.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331805"
#             },
#             {
#                 "answer_text": "I\u2019m a returning customer, always satisfied with your prompt service.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331812"
#             },
#             {
#                 "answer_text": "I'm an existing customer with a problem I need resolved quickly.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331820"
#             },
#             {
#                 "answer_text": "I'm a customer who has recommended your service to others.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331828"
#             },
#             {
#                 "answer_text": "I'm a returning customer and a satisfied user of your platform.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331836"
#             },
#             {
#                 "answer_text": "I'm an existing customer with a payment-related inquiry.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331843"
#             },
#             {
#                 "answer_text": "I'm a highly valued customer with extensive purchasing history.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331852"
#             },
#             {
#                 "answer_text": "I'm a loyal customer, and I\u2019m looking forward to future purchases.",
#                 "answer_label": "Existing customer",
#                 "timestamp": "2025-01-24T00:52:36.331860"
#             },
#             {
#                 "answer_text": "I'm an existing customer actively involved in your community.",
#                 "answer_label": "Existing customer",
# ...
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563283"
#             },
#             {
#                 "answer_text": "The specific customer group is R&D scientists developing new diagnostic tools.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563289"
#             },
#             {
#                 "answer_text": "Our focus is on R&D teams working on sustainable transportation solutions.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563295"
#             },
#             {
#                 "answer_text": "We're targeting R&D professionals working in the field of artificial intelligence for healthcare.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563302"
#             },
#             {
#                 "answer_text": "The customer group is R&D engineers in the telecommunications industry.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563308"
#             },
#             {
#                 "answer_text": "Our ideal customer is the R&D division of a large technology company.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563314"
#             },
#             {
#                 "answer_text": "We're concentrating on R&D professionals working on cybersecurity solutions.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563321"
#             },
#             {
#                 "answer_text": "Our target market includes R&D engineers involved in the development of self-driving cars.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563327"
#             },
#             {
#                 "answer_text": "Our specific customer base is R&D personnel in the food and beverage industry.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563334"
#             },
#             {
#                 "answer_text": "We're aiming to reach R&D professionals working in the field of big data analytics.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563340"
#             },
#             {
#                 "answer_text": "The specific customer group is R&D scientists developing new energy sources.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563350"
#             },
#             {
#                 "answer_text": "Our focus is on R&D teams in the construction industry.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563361"
#             },
#             {
#                 "answer_text": "We're targeting R&D professionals working in the field of renewable energy.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563368"
#             },
#             {
#                 "answer_text": "The customer group is R&D engineers developing smart home technologies.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563374"
#             },
#             {
#                 "answer_text": "Our ideal customer is the R&D division of a large manufacturing company.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563380"
#             },
#             {
#                 "answer_text": "We're concentrating on R&D professionals working on advanced manufacturing techniques.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563386"
#             },
#             {
#                 "answer_text": "Our target market includes R&D engineers involved in the development of 3D printing technologies.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563392"
#             },
#             {
#                 "answer_text": "Our specific customer base is R&D personnel in the logistics industry.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563398"
#             },
#             {
#                 "answer_text": "We're aiming to reach R&D professionals working in the field of supply chain management.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563404"
#             },
#             {
#                 "answer_text": "The specific customer group is R&D scientists developing new agricultural technologies.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563410"
#             },
#             {
#                 "answer_text": "Our focus is on R&D teams working on precision farming techniques.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563416"
#             },
#             {
#                 "answer_text": "We're targeting R&D professionals working in the field of sustainable agriculture.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563422"
#             },
#             {
#                 "answer_text": "The customer group is R&D engineers developing new water management technologies.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563428"
#             },
#             {
#                 "answer_text": "Our ideal customer is the R&D division of a large water utility company.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563434"
#             },
#             {
#                 "answer_text": "We're concentrating on R&D professionals working on water conservation techniques.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563440"
#             },
#             {
#                 "answer_text": "Our target market includes R&D engineers involved in the development of water purification technologies.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563446"
#             },
#             {
#                 "answer_text": "Our specific customer base is R&D personnel in the environmental consulting industry.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563452"
#             },
#             {
#                 "answer_text": "We're aiming to reach R&D professionals working in the field of environmental remediation.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563458"
#             },
#             {
#                 "answer_text": "The specific customer group is R&D scientists developing new environmental monitoring technologies.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563468"
#             },
#             {
#                 "answer_text": "Our focus is on R&D teams working on climate change mitigation strategies.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563474"
#             },
#             {
#                 "answer_text": "We're targeting R&D professionals working in the field of climate change adaptation.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563480"
#             },
#             {
#                 "answer_text": "The customer group is R&D engineers developing new climate modeling techniques.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563486"
#             },
#             {
#                 "answer_text": "Our ideal customer is the R&D division of a large environmental agency.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563493"
#             },
#             {
#                 "answer_text": "We're concentrating on R&D professionals working on sustainable development goals.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563499"
#             },
#             {
#                 "answer_text": "Our target market includes R&D engineers involved in the development of circular economy models.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563505"
#             },
#             {
#                 "answer_text": "Our specific customer base is R&D personnel in the sustainable tourism industry.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563511"
#             },
#             {
#                 "answer_text": "We're aiming to reach R&D professionals working in the field of ecotourism.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563517"
#             },
#             {
#                 "answer_text": "The specific customer group is R&D scientists developing new sustainable packaging technologies.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563523"
#             },
#             {
#                 "answer_text": "Our focus is on R&D teams working on reducing waste in the manufacturing industry.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563529"
#             },
#             {
#                 "answer_text": "We're targeting R&D professionals working in the field of sustainable fashion.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563535"
#             },
#             {
#                 "answer_text": "The customer group is R&D engineers developing new sustainable building materials.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563541"
#             },
#             {
#                 "answer_text": "Our ideal customer is the R&D division of a large construction company.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563547"
#             },
#             {
#                 "answer_text": "We're concentrating on R&D professionals working on sustainable urban planning.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563556"
#             },
#             {
#                 "answer_text": "Our target market includes R&D engineers involved in the development of green infrastructure.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563562"
#             },
#             {
#                 "answer_text": "Our specific customer base is R&D personnel in the renewable energy sector.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563569"
#             },
#             {
#                 "answer_text": "We're aiming to reach R&D professionals working in the field of solar energy.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563575"
#             },
#             {
#                 "answer_text": "The specific customer group is R&D scientists developing new wind energy technologies.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563581"
#             },
#             {
#                 "answer_text": "Our focus is on R&D teams working on energy efficiency improvements.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563587"
#             },
#             {
#                 "answer_text": "We're targeting R&D professionals working in the field of energy storage.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563593"
#             },
#             {
#                 "answer_text": "The customer group is R&D engineers developing new battery technologies.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563600"
#             },
#             {
#                 "answer_text": "Our ideal customer is the R&D division of a large utility company.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563606"
#             },
#             {
#                 "answer_text": "We're concentrating on R&D professionals working on smart grid technologies.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563613"
#             },
#             {
#                 "answer_text": "Our target market includes R&D engineers involved in the development of microgrids.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563619"
#             },
#             {
#                 "answer_text": "Our specific customer base is R&D personnel in the aerospace industry.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563625"
#             },
#             {
#                 "answer_text": "We're aiming to reach R&D professionals working in the field of aviation.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563631"
#             },
#             {
#                 "answer_text": "The specific customer group is R&D scientists developing new aerospace materials.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563637"
#             },
#             {
#                 "answer_text": "Our focus is on R&D teams working on advanced aircraft design.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563643"
#             },
#             {
#                 "answer_text": "We're targeting R&D professionals working in the field of space exploration.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563649"
#             },
#             {
#                 "answer_text": "The customer group is R&D engineers developing new satellite technologies.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563655"
#             },
#             {
#                 "answer_text": "Our ideal customer is the R&D division of a large space agency.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563661"
#             },
#             {
#                 "answer_text": "We're concentrating on R&D professionals working on robotics and automation.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563667"
#             },
#             {
#                 "answer_text": "Our target market includes R&D engineers involved in the development of drones.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563673"
#             },
#             {
#                 "answer_text": "Our specific customer base is R&D personnel in the defense industry.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563679"
#             },
#             {
#                 "answer_text": "We're aiming to reach R&D professionals working in the field of cybersecurity.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563685"
#             },
#             {
#                 "answer_text": "The specific customer group is R&D scientists developing new defense technologies.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563691"
#             },
#             {
#                 "answer_text": "Our focus is on R&D teams working on national security.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563697"
#             },
#             {
#                 "answer_text": "We're targeting R&D professionals working in the field of intelligence.",
#                 "answer_label": "R&D",
#                 "timestamp": "2025-01-24T01:06:02.563704"
#             }
#         ]
#     }
# ]

# %%
#df_single_select_questions['Question'] = df_single_select_questions['Question'].map(generated_single_select_questions)

# %%
#df_single_select_questions
